# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Ploting small scale graph

# %%
xs = [0.3, 1, 2.2, 3.5]
ys = [1.9, 3.3, 0.3, 3.2]
fig,ax = plt.subplots(1,1)
ax.plot(np.array([0.3,1]),np.array([1.9,3.3]),'k--')
ax.plot([1,2.2],[3.3,0.3],'k--')
ax.plot([1,3.5],[3.3,3.2],'k--')
ax.plot([0.3,2.2],[1.9,0.3],'k--')
#ax.plot([1, 2, 3, 1.5], [1, 4, 9, 8], 'yo',label='stay points')
ax.plot(xs,ys,'go',label='stay points')
ax.set_xlabel("x(m)")
ax.set_ylabel("y(m)")
ax.legend()

# %% [markdown]
# ## Ploting greedy solution to small scale

# %%
xs = [0.3, 1, 2.2, 3.5]
ys = [1.9, 3.3, 0.3, 3.2]
charger_x = [0.5,0.5,1.5,3.5,1.5,2.5]
charger_y = [2.5,1.5,3.5,3.5,2.5,0.5]
fig,ax = plt.subplots(1,1)
ax.plot(np.array([0.3,1]),np.array([1.9,3.3]),'k--')
ax.plot([1,2.2],[3.3,0.3],'k--')
ax.plot([1,3.5],[3.3,3.2],'k--')
ax.plot([0.3,2.2],[1.9,0.3],'k--')
#ax.plot([1, 2, 3, 1.5], [1, 4, 9, 8], 'yo',label='stay points')
ax.plot(xs,ys,'go',label='stay points')
ax.plot(charger_x,charger_y,'rx',label="chargers")
ax.set_xlabel("x(m)")
ax.set_ylabel("y(m)")
ax.legend()

# %% [markdown]
# ## Ploting Pso solution to small scale

# %%
xs = [0.3, 1, 2.2, 3.5]
ys = [1.9, 3.3, 0.3, 3.2]
charger_x = [3.206816,0.409683,2.102025,1.099591]
charger_y = [3.260254,1.824016,0.395991,3.196083]
fig,ax = plt.subplots(1,1)
ax.plot(np.array([0.3,1]),np.array([1.9,3.3]),'k--')
ax.plot([1,2.2],[3.3,0.3],'k--')
ax.plot([1,3.5],[3.3,3.2],'k--')
ax.plot([0.3,2.2],[1.9,0.3],'k--')
#ax.plot([1, 2, 3, 1.5], [1, 4, 9, 8], 'yo',label='stay points')
ax.plot(xs,ys,'go',label='stay points')
ax.plot(charger_x,charger_y,'rx',label="chargers")
ax.set_xlabel("x(m)")
ax.set_ylabel("y(m)")
ax.legend()

# %% [markdown]
# # Ploting bar plot on variated $P_s$ (Small scale)

# %%
bar_width=0.35
names_1 = np.arange(2,6)
greedy_chargers = [6,5,4,4]
pso_chargers = [4,4,3,3]
fig,ax = plt.subplots(1,1)
ax.bar(names_1,greedy_chargers,bar_width,label='Greedy Heuristic')
ax.bar(names_1 + bar_width,pso_chargers,bar_width,label='Pso')
ax.set_xlabel("$P_s$ (w)")
ax.set_ylabel("Number of Chargers placed")
ax.set_xticks(names_1 + bar_width/2)
ax.set_xticklabels((2, 3, 4, 5))
ax.legend()

# %% [markdown]
# # Ploting bar plot on variated $P_c$ (Small scale)

# %%
bar_width=0.35
names_1 = np.arange(6,10)
greedy_chargers_1 = [6,6,7,9]
pso_chargers_1 = [4,4,5,5]
fig,ax = plt.subplots(1,1)
ax.bar(names_1,greedy_chargers_1,bar_width,label='Greedy Heuristic')
ax.bar(names_1 + bar_width,pso_chargers_1,bar_width,label='Pso')
ax.set_xlabel("$Pc$ (mw)")
ax.set_ylabel("Number of Chargers placed")
ax.set_xticks(names_1 + bar_width/2)
ax.set_xticklabels((6, 7, 8, 9))
ax.legend()

# %% [markdown]
# # Ploting bar plot on variated $p_{th}$ (Small Scale)

# %%
bar_width=0.35
names_1_1 = np.arange(6,11)
greedy_chargers_1 = [6,6,6,6,6]
pso_chargers_1 = [4,4,4,4,4]
fig,ax = plt.subplots(1,1)
ax.bar(names_1_1,greedy_chargers_1,bar_width,label='Greedy Heuristic')
ax.bar(names_1_1 + bar_width,pso_chargers_1,bar_width,label='Pso')
ax.set_xlabel("$pth$")
ax.set_ylabel("Number of Chargers placed")
ax.set_xticks(names_1 + bar_width/2)
ax.set_xticklabels((0.8, 0.85, 0.9, 0.95,1))
ax.legend()

# %% [markdown]
# # Ploting large scale graph information from file

# %%
graph_info_path = 'results/large_scale_graph_information.txt'

# %%
with open(graph_info_path,'r') as f:
    lines=f.readlines()
    x_str = lines[1].split(',')
    x_str = x_str[0:len(x_str)-1]
    x_coordinate = []
    for item in x_str:
        x_coordinate.append(float(item))
    y_str = lines[2].split(',')
    y_str = y_str[0:len(y_str)-1]
    y_coordinate = []
    for item in y_str:
        y_coordinate.append(float(item))
    print(x_coordinate)
    print(y_coordinate)
    fig,ax = plt.subplots(1,1)
    ax.plot(x_coordinate,y_coordinate,'go',label='staypoints')
    lines = lines[4:len(lines)]
    for line in lines:
        line_split = line.split(',')
        x_1 = float(line_split[0])
        y_1 = float(line_split[1])
        x_2 = float(line_split[2])
        y_2 = float(line_split[3])
        ax.plot([x_1,x_2],[y_1,y_2],'k--')
    ax.set_xlabel('x(m)')
    ax.set_ylabel('y(m)')
    ax.legend()
f.close()
# Out:
# [2.0, 6.2, 3.48, 11.46, 12.0, 5.4, 20.0, 54.82, 27.12, 37.89, 15.37, 47.13, 47.97, 54.68, 47.13, 40.0]
# [3.0, 17.8, 13.0, 8.57, 46.0, 41.2, 40.0, 7.03, 20.88, 44.52, 34.58, 5.07, 48.85, 32.35, 40.88, 20.0]

# %%
"vertices" == "vertices"
# Out:
# True

# %% [markdown]
# # Ploting large scale greedy solution result

# %%
graph_info_path = 'results/large_scale_graph_information.txt'
greedy_placement_path = 'results/greedySolution.txt'
fig,ax = plt.subplots(1,1)
with open(graph_info_path,'r') as f:
    lines=f.readlines()
    x_str = lines[1].split(',')
    x_str = x_str[0:len(x_str)-1]
    x_coordinate = []
    for item in x_str:
        x_coordinate.append(float(item))
    y_str = lines[2].split(',')
    y_str = y_str[0:len(y_str)-1]
    y_coordinate = []
    for item in y_str:
        y_coordinate.append(float(item))
    print(x_coordinate)
    print(y_coordinate)
    ax.plot(x_coordinate,y_coordinate,'go',label='staypoints')
    lines = lines[4:len(lines)]
    for line in lines:
        line_split = line.split(',')
        x_1 = float(line_split[0])
        y_1 = float(line_split[1])
        x_2 = float(line_split[2])
        y_2 = float(line_split[3])
        ax.plot([x_1,x_2],[y_1,y_2],'k--')
    
f.close()
with open(greedy_placement_path,'r') as f:
    lines = f.readlines()
    x = []
    y = []
    for line in lines:
        line_split = line.split(',')
        x.append(float(line_split[0]))
        y.append(float(line_split[1]))
    ax.plot(x,y,'rx',label='Chargers')
ax.set_xlabel('x(m)')
ax.set_ylabel('y(m)')
ax.legend()
# Out:
# [2.0, 6.2, 3.48, 11.46, 12.0, 5.4, 20.0, 54.82, 27.12, 37.89, 15.37, 47.13, 47.97, 54.68, 47.13, 40.0]
# [3.0, 17.8, 13.0, 8.57, 46.0, 41.2, 40.0, 7.03, 20.88, 44.52, 34.58, 5.07, 48.85, 32.35, 40.88, 20.0]

# %% [markdown]
# # Ploting large scale pso solution results

# %%
graph_info_path = 'results/large_scale_graph_information.txt'
greedy_placement_path = 'results/psoSolution.txt'
fig,ax = plt.subplots(1,1)
with open(graph_info_path,'r') as f:
    lines=f.readlines()
    x_str = lines[1].split(',')
    x_str = x_str[0:len(x_str)-1]
    x_coordinate = []
    for item in x_str:
        x_coordinate.append(float(item))
    y_str = lines[2].split(',')
    y_str = y_str[0:len(y_str)-1]
    y_coordinate = []
    for item in y_str:
        y_coordinate.append(float(item))
    print(x_coordinate)
    print(y_coordinate)
    ax.plot(x_coordinate,y_coordinate,'go',label='staypoints')
    lines = lines[4:len(lines)]
    for line in lines:
        line_split = line.split(',')
        x_1 = float(line_split[0])
        y_1 = float(line_split[1])
        x_2 = float(line_split[2])
        y_2 = float(line_split[3])
        ax.plot([x_1,x_2],[y_1,y_2],'k--')
    
f.close()
with open(greedy_placement_path,'r') as f:
    lines = f.readlines()
    x = []
    y = []
    for line in lines:
        line_split = line.split(',')
        x.append(float(line_split[0]))
        y.append(float(line_split[1]))
    ax.plot(x,y,'rx',label='Chargers')
ax.set_xlabel('x(m)')
ax.set_ylabel('y(m)')
ax.legend()
# Out:
# [2.0, 6.2, 3.48, 11.46, 12.0, 5.4, 20.0, 54.82, 27.12, 37.89, 15.37, 47.13, 47.97, 54.68, 47.13, 40.0]
# [3.0, 17.8, 13.0, 8.57, 46.0, 41.2, 40.0, 7.03, 20.88, 44.52, 34.58, 5.07, 48.85, 32.35, 40.88, 20.0]

# %%
bar_width=0.35
names_1 = np.arange(2,6)
greedy_chargers = [54,47,43,38]
pso_chargers = [38,36,31,28]
fig,ax = plt.subplots(1,1)
ax.bar(names_1,greedy_chargers,bar_width,label='Greedy Heuristic')
ax.bar(names_1 + bar_width,pso_chargers,bar_width,label='Pso')
ax.set_xlabel("$P_s$ (w)")
ax.set_ylabel("Number of Chargers placed")
ax.set_xticks(names_1 + bar_width/2)
ax.set_xticklabels((2, 3, 4, 5))
ax.legend()

# %%
bar_width=0.35
names_1_1 = np.arange(6,10)
greedy_chargers_1 = [45,51,60,70]
pso_chargers_1 = [35,40,42,44]
fig,ax = plt.subplots(1,1)
ax.bar(names_1_1,greedy_chargers_1,bar_width,label='Greedy Heuristic')
ax.bar(names_1_1 + bar_width,pso_chargers_1,bar_width,label='Pso')
ax.set_xlabel("$Pc$ (mw)")
ax.set_ylabel("Number of Chargers placed")
ax.set_xticks(names_1_1 + bar_width/2)
ax.set_xticklabels((6, 7, 8, 9))
ax.legend()

# %%
bar_width=0.35
names_1_1 = np.arange(6,11)
greedy_chargers_1 = [48,52,68,79,90]
pso_chargers_1 = [36,40,45,48,53]
fig,ax = plt.subplots(1,1)
ax.bar(names_1_1,greedy_chargers_1,bar_width,label='Greedy Heuristic')
ax.bar(names_1_1 + bar_width,pso_chargers_1,bar_width,label='Pso')
ax.set_xlabel("$pth$")
ax.set_ylabel("Number of Chargers placed")
ax.set_xticks(names_1_1 + bar_width/2)
ax.set_xticklabels((0.8, 0.85, 0.9, 0.95,1))
ax.legend()
